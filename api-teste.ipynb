# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
url = "https://restcountries.com/v3.1/all"
response=requests.get(url)

# %%
if response.status_code == 200:
    data_json = response.json()
else:
    print('Erro ao acessar a API')

# %%
df = pd.DataFrame(data_json)

# %%
df.head(3)
# Out:
#                                                 name    tld cca2 ccn3 cca3  \
# 0  {'common': 'South Georgia', 'official': 'South...  [.gs]   GS  239  SGS
# 1  {'common': 'Grenada', 'official': 'Grenada', '...  [.gd]   GD  308  GRD
# 2  {'common': 'Switzerland', 'official': 'Swiss C...  [.ch]   CH  756  CHE
#
#   independent               status  unMember  \
# 0       False  officially-assigned     False
# 1        True  officially-assigned      True
# 2        True  officially-assigned      True
#
#                                           currencies  \
# 0  {'SHP': {'name': 'Saint Helena pound', 'symbol...
# 1  {'XCD': {'name': 'Eastern Caribbean dollar', '...
# 2  {'CHF': {'name': 'Swiss franc', 'symbol': 'Fr.'}}
#
#                                    idd              capital  \
# 0   {'root': '+5', 'suffixes': ['00']}  [King Edward Point]
# 1  {'root': '+1', 'suffixes': ['473']}       [St. George's]
# 2    {'root': '+4', 'suffixes': ['1']}               [Bern]
#
# ...

# %%
df.describe()
# Out:
#                area    population
# count  2.500000e+02  2.500000e+02
# mean   6.005848e+05  3.111089e+07
# std    1.909805e+06  1.296673e+08
# min    4.400000e-01  0.000000e+00
# 25%    1.194250e+03  2.210995e+05
# 50%    6.492950e+04  4.912244e+06
# 75%    3.727260e+05  1.902577e+07
# max    1.709824e+07  1.402112e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          250 non-null    object
#  1   tld           249 non-null    object
#  2   cca2          250 non-null    object
#  3   ccn3          249 non-null    object
#  4   cca3          250 non-null    object
#  5   independent   249 non-null    object
#  6   status        250 non-null    object
#  7   unMember      250 non-null    bool
#  8   currencies    247 non-null    object
#  9   idd           250 non-null    object
#  10  capital       246 non-null    object
#  11  altSpellings  250 non-null    object
#  12  region        250 non-null    object
#  13  languages     249 non-null    object
#  14  translations  250 non-null    object
#  15  latlng        250 non-null    object
#  16  landlocked    250 non-null    bool
#  17  area          250 non-null    float64
# ...

# %%
data = [
    {
        "name": {"common": "South Georgia", "official": "South Georgia and the South Sandwich Islands"},
        "region": None,
        "population": None
    },
    {
        "name": {"common": "Grenada", "official": "Grenada"},
        "region": "Caribbean",
        "population": 112519
    },
    {
        "name": {"common": "Switzerland", "official": "Swiss Confederation"},
        "region": "Western Europe",
        "population": 8654622
    }
]

# %%
nome = [pais['name']['common'] for pais in data]

# %%
regiao = [pais.get('region', 'Desconhecida') for pais in data]

# %%
populacao = [pais.get('population', 'Desconhecida') for pais in data]

# %%
paises = pd.DataFrame({
    "Nome": nome,
    "Região": regiao,
    "População": populacao
})

# %%
paises.head(3)
# Out:
#             Nome          Região  População
# 0  South Georgia            None        NaN
# 1        Grenada       Caribbean   112519.0
# 2    Switzerland  Western Europe  8654622.0
